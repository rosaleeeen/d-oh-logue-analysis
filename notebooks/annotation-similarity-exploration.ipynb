# %%
import pandas as pd

burns_df = pd.read_csv("../data/Final_annotated_scripts/c_montgomery_burns_lines_annotated.csv")
flanders_df = pd.read_csv("../data/Final_annotated_scripts/ned_flanders_lines_annotated.csv")
seymour_df = pd.read_csv("../data/Final_annotated_scripts/seymour_skinner_lines_annotated.csv")

df = pd.concat([burns_df, flanders_df, seymour_df], ignore_index=True)

# %%
# quantity of annotation agreement
df[df["Serhii_annotation"] == df["Laura_annotation"]].count()
# Out:
# raw_character_text     418
# Laura_annotation       418
# Serhii_annotation      418
# Rosaleen_annotation      0
# spoken_words           418
# dtype: int64

# %%
# frequency of annotation agreement
df[df["Serhii_annotation"] == df["Laura_annotation"]].count() / df.count()
# Out:
# raw_character_text     0.464444
# Laura_annotation       0.464444
# Serhii_annotation      0.464444
# Rosaleen_annotation         NaN
# spoken_words           0.464444
# dtype: float64

# %%
# the majority of the lines have different type annotations => perhaps the typology requires refinement
